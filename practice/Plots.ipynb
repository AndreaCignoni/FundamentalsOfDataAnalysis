# %% [markdown]
# # Plots
#
# ***

# %%
# Plots.
import matplotlib.pyplot as plt

# Fancier plots.
import seaborn as sns

# %%
# Numerical arrays.
import numpy as np

# %% [markdown]
# $ f(x) = x^2 -4x+4$

# %%
# The above f function
def f(x):
    return x**2 - (4.0*x) + 4.0

# %%
# Array of x value.
x = np.linspace(-1.0, 5.0, 601)

# %%
# Calculate the y values.
y = f(x)

# %%
y
# Out:
# array([9.0000e+00, 8.9401e+00, 8.8804e+00, 8.8209e+00, 8.7616e+00,
#        8.7025e+00, 8.6436e+00, 8.5849e+00, 8.5264e+00, 8.4681e+00,
#        8.4100e+00, 8.3521e+00, 8.2944e+00, 8.2369e+00, 8.1796e+00,
#        8.1225e+00, 8.0656e+00, 8.0089e+00, 7.9524e+00, 7.8961e+00,
#        7.8400e+00, 7.7841e+00, 7.7284e+00, 7.6729e+00, 7.6176e+00,
#        7.5625e+00, 7.5076e+00, 7.4529e+00, 7.3984e+00, 7.3441e+00,
#        7.2900e+00, 7.2361e+00, 7.1824e+00, 7.1289e+00, 7.0756e+00,
#        7.0225e+00, 6.9696e+00, 6.9169e+00, 6.8644e+00, 6.8121e+00,
#        6.7600e+00, 6.7081e+00, 6.6564e+00, 6.6049e+00, 6.5536e+00,
#        6.5025e+00, 6.4516e+00, 6.4009e+00, 6.3504e+00, 6.3001e+00,
#        6.2500e+00, 6.2001e+00, 6.1504e+00, 6.1009e+00, 6.0516e+00,
#        6.0025e+00, 5.9536e+00, 5.9049e+00, 5.8564e+00, 5.8081e+00,
#        5.7600e+00, 5.7121e+00, 5.6644e+00, 5.6169e+00, 5.5696e+00,
#        5.5225e+00, 5.4756e+00, 5.4289e+00, 5.3824e+00, 5.3361e+00,
# ...

# %%
#Create an empty plot.
fig, ax = plt.subplots()

# Interpolate.
ax.plot(x, y)

# %% [markdown]
# ***
#
# ## Styles
#
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.use('ggplot')

# %%
#Create an empty plot.
fig, ax = plt.subplots()

# Interpolate.
ax.plot(x, y)

# %%
plt.style.use('fivethirtyeight')

# %%
#Create an empty plot.
fig, ax = plt.subplots()

# Interpolate.
ax.plot(x, y)

# %%
plt.xkcd()

# %%
with plt.xkcd():
    #Create an empty plot.
    fig, ax = plt.subplots()

    # Interpolate.
    ax.plot(x, y)

# %% [markdown]
# ***
#
# ## Seaborn

# %%
# From: https://seaborn.pydata.org/examples/scatterplot_matrix.html
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species", diag_kind = "hist")

plt.show()

# %% [markdown]
# ***
#
# ## Plots of Different Functions

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Range of x values.
x = np.linspace(-12.0, 12.0, 801)

# Plot x^2.
ax.plot(x, x**2, label= '$x^2$')

# Plot x^2 + x.
ax.plot(x, x**2 + x, label= '$x^2 + x$')

# Plot x^2 - x.
ax.plot(x, x**2 - x, label = '$x^2 - x$')

# Plot x^2 - 3.0.
ax.plot(x, x**2 - (4 * x), label = '$x^2 - 4x$')

# Turn on legend.
ax.legend();

plt.show()

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Range of x values.
x = np.linspace(1.0, 10.0, 1001)

# Plot log (natural).
ax.plot(x, np.log(x), label= '$\ln(x)$')

# Plot log base 2.
ax.plot(x, np.log2(x), label='$\log_2(x)$')

# Plot log base 10.
ax.plot(x, np.log10(x), label='$\log_{10}(x)$')

# Turn on legend.
ax.legend();

plt.show()

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Plot x^2.
ax.plot(x, x**2, label= '$x^2$')

# Plot x^2 + 1.0.
ax.plot(x, x**2 + 1, label= '$x^2 + 1$')

# Plot x^2 - 2.0.
ax.plot(x, x**2 - 2.0, label = '$x^2 - 2$')

# Plot x^2 - 3.0.
ax.plot(x, x**2 - 3.0, label = '$x^2 - 3$')

# Turn on legend.
ax.legend();

plt.show()

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Plot x^2.
ax.plot(x, x**2, label= '$x^2$')

# Plot x^2 + x.
ax.plot(x, x**2 + x, label= '$x^2 + x$')

# Plot x^2 - x.
ax.plot(x, x**2 - x, label = '$x^2 - x$')

# Plot x^2 - 4.0.
ax.plot(x, x**2 - (4.0 * x), label = '$x^2 - 4x$')

# Turn on legend.
ax.legend();

plt.show()

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Range of x values.
x = np.linspace(-3.0, 3.0, 1001)

# Plot x.
ax.plot(x, label= '$x$')

# Plot x^2.
ax.plot(x, x**2, label= '$x^2$')

# Plot x^3.
ax.plot(x, x**3, label= '$x^3$')

# Plot x^4.
ax.plot(x, x**4, label= '$x^4$')

# Turn on legend.
ax.legend();

plt.show()

# %%
# Create an empty plot.
fig, ax = plt.subplots()

# Range of x values.
x = np.linspace(0.0, 50.0)

# Plot x.
ax.plot(x, label= '$x$')

# Plot x^2.
ax.plot(x, x**2, label= '$x^2$')

# Plot 2^x.
ax.plot(x, 2**x, label= '$2^x$')

# Turn on legend.
ax.legend();

plt.show()

# %% [markdown]
# ***
#
# # End
